# %%
import json
import requests
import csv
import io
from rich import print as rprint
import pandas as pd
import pprint

# %%
genesis_url = 'https://www-genesis.destatis.de/genesisWS/rest/2020/catalogue/timeseries?'
user_id = 'DE17T29R57'
password = '4Bf/3Ap)3]r2,,h'
selection = '61241*'
area = "all"
pagelength = "20"
language = "de"

lang = 'en'

# find the details for a specific Index
destatis = f"{genesis_url}username={user_id}&password={password}&name={name}&selection={selection}&area={area}&pagelength={pagelength}&language={language}"

# get data from GENESIS API, converts it to JSON, get the CSV content and splits the lines
responseContent = json.loads(requests.get(destatis).text)
rprint(responseContent)
# Out:
# {
#     'Ident': {'Service': 'catalogue', 'Method': 'timeseries'},
#     'Status': {'Code': 0, 'Content': 'erfolgreich', 'Type': 'Information'},
#     'Parameter': {
#         'username': '********************',
#         'password': '********************',
#         'selection': '61241*',
#         'area': 'Alle',
#         'pagelength': '20',
#         'language': 'de'
#     },
#     'List': [
#         {
#             'Code': '61241BJ001',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# Deutschland insgesamt, Jahr',
#             'State': 'undefiniert',
#             'Time': '2021-2023',
#             'LatestUpdate': '13.03.2024 14:41:24h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BJ002',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (2-Steller): Gewerbliche Produkte, Deutschland insgesamt, Jahr',
#             'State': 'undefiniert',
#             'Time': '2021-2023',
#             'LatestUpdate': '13.03.2024 14:42:23h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BJ003',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (3-Steller): Gewerbliche Produkte, Deutschland insgesamt, Jahr',
#             'State': 'undefiniert',
#             'Time': '2021-2023',
#             'LatestUpdate': '13.03.2024 14:42:26h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BJ004',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (4-Steller): Gewerbliche Produkte, Deutschland insgesamt, Jahr',
#             'State': 'undefiniert',
#             'Time': '2021-2023',
#             'LatestUpdate': '13.03.2024 14:42:30h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BJ005',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (5-Steller): Gewerbliche Produkte, Deutschland insgesamt, Jahr',
#             'State': 'undefiniert',
#             'Time': '2021-2023',
#             'LatestUpdate': '13.03.2024 14:44:14h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BJ006',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (6-Steller): Gewerbliche Produkte, Deutschland insgesamt, Jahr',
#             'State': 'undefiniert',
#             'Time': '2021-2023',
#             'LatestUpdate': '13.03.2024 14:43:25h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BJ007',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (ausgewählte 9-Steller): Gewerbl. Produkte, Deutschland insgesamt, Jahr',
#             'State': 'undefiniert',
#             'Time': '2021-2023',
#             'LatestUpdate': '13.03.2024 14:43:49h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BJ008',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (Sonderpositionen): Gewerbliche Produkte, Deutschland insgesamt, Jahr',
#             'State': 'undefiniert',
#             'Time': '2021-2023',
#             'LatestUpdate': '13.03.2024 14:44:18h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM001',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# Deutschland insgesamt, Monate, Jahr',
#             'State': 'undefiniert',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:00:44h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM002',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (2-Steller): Gewerbliche Produkte, Deutschland insgesamt, Monate, Jahr',
#             'State': 'undefiniert',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:00:38h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM003',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (3-Steller): Gewerbliche Produkte, Deutschland insgesamt, Monate, Jahr',
#             'State': 'undefiniert',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:01:02h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM004',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (4-Steller): Gewerbliche Produkte, Deutschland insgesamt, Monate, Jahr',
#             'State': 'undefiniert',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:00:58h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM005',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (5-Steller): Gewerbliche Produkte, Deutschland insgesamt, Monate, Jahr',
#             'State': 'undefiniert',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:00:54h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM006',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (6-Steller): Gewerbliche Produkte, Deutschland insgesamt, Monate, Jahr',
#             'State': 'undefiniert',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:01:08h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM007',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (ausgewählte 9-Steller): Gewerbl. Produkte, Deutschland insgesamt, Monate, Jahr',
#             'State': 'undefiniert',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:00:50h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM008',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (Sonderpositionen): Gewerbliche Produkte, Deutschland insgesamt, Monate, Jahr',
#             'State': 'undefiniert',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:00:41h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM010',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreise für leichtes Heizöl, Art der
# Lieferung (leichtes Heizöl), Berichtsort bzw. Geltungsbereich (leichtes Heizöl), Monate, Jahr',
#             'State': 'undefiniert',
#             'Time': 'Januar 1976-März 2024',
#             'LatestUpdate': '12.04.2024 08:04:59h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM011',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreise für schweres Heizöl, Art der
# Lieferung (schweres Heizöl), Berichtsort bzw. Geltungsbereich (schweres Heizöl), Monate, Jahr',
#             'State': 'undefiniert',
#             'Time': 'Januar 1991-Dezember 2016',
#             'LatestUpdate': '21.02.2017 16:08:54h',
#             'Information': 'false'
#         }
#     ],
#     'Copyright': '© Statistisches Bundesamt (Destatis), 2024'
# }

# %%
genesis_url = 'https://www-genesis.destatis.de/genesisWS/rest/2020/catalogue/cubes2variable?'
user_id = 'DE17T29R57'
password = '4Bf/3Ap)3]r2,,h'
name = "Kreise"
selection = '61241*'
area = "all"
pagelength = "20"
language = "de"

lang = 'en'

# find the details for a specific Index
destatis = f"{genesis_url}username={user_id}&password={password}&name={name}&selection={selection}&area={area}&pagelength={pagelength}&language={language}"

# get data from GENESIS API, converts it to JSON, get the CSV content and splits the lines
responseContent = json.loads(requests.get(destatis).text)
rprint(responseContent)
# Out:
# {
#     'Ident': {'Service': 'catalogue', 'Method': 'cubes2variable'},
#     'Status': {
#         'Code': 104,
#         'Content': 'Es gibt keine Objekte zum angegebenen Selektionskriterium',
#         'Type': 'Information'
#     },
#     'Parameter': {
#         'username': '********************',
#         'password': '********************',
#         'name': 'Kreise',
#         'selection': '61241*',
#         'area': 'Alle',
#         'pagelength': '20',
#         'language': 'de'
#     },
#     'List': None,
#     'Copyright': '© Statistisches Bundesamt (Destatis), 2024'
# }

# %%
genesis_url = 'https://www-genesis.destatis.de/genesisWS/rest/2020/find/find?'
user_id = 'DE17T29R57'
password = '4Bf/3Ap)3]r2,,h'
term = "Erzeugerpreisindex gewerblicher Produkte: Deutschland, Monate, Güterverzeichnis (GP2019 2-/3-/4-/5-/6-/9-Steller/Sonderpositionen) "
category = "all"
pagelength = "20"
language = "de"

lang = 'en'

# find the details for a specific Index
destatis = f"{genesis_url}username={user_id}&password={password}&term={term}&category={category}&pagelength={pagelength}&language={language}"

# get data from GENESIS API, converts it to JSON, get the CSV content and splits the lines
responseContent = json.loads(requests.get(destatis).text)
rprint(responseContent)
# Out:
# {
#     'Ident': {'Service': 'find', 'Method': 'find'},
#     'Status': {'Code': 0, 'Content': 'erfolgreich', 'Type': 'Information'},
#     'Parameter': {
#         'username': '********************',
#         'password': '********************',
#         'term': 'Erzeugerpreisindex gewerblicher Produkte: Deutschland, Monate, Güterverzeichnis (GP2019
# 2-/3-/4-/5-/6-/9-Steller/Sonderpositionen)',
#         'category': 'Alle',
#         'pagelength': '20',
#         'language': 'de'
#     },
#     'Cubes': None,
#     'Statistics': None,
#     'Tables': None,
#     'Timeseries': None,
#     'Variables': None,
#     'Copyright': '© Statistisches Bundesamt (Destatis), 2024'
# }

# %%
genesis_url = 'https://www-genesis.destatis.de/genesisWS/rest/2020/catalogue/cubes?'
user_id = 'DE17T29R57'
password = '4Bf/3Ap)3]r2,,h'
selection = "61241BM*"
category = "all"
pagelength = "20"
language = "de"

lang = 'en'

# find the details for a specific Index
destatis = f"{genesis_url}username={user_id}&password={password}&selection={selection}&category={category}&pagelength={pagelength}&language={language}"

# get data from GENESIS API, converts it to JSON, get the CSV content and splits the lines
responseContent = json.loads(requests.get(destatis).text)
rprint(responseContent)
# Out:
# {
#     'Ident': {'Service': 'catalogue', 'Method': 'cubes'},
#     'Status': {'Code': 0, 'Content': 'erfolgreich', 'Type': 'Information'},
#     'Parameter': {
#         'username': '********************',
#         'password': '********************',
#         'selection': '61241BM*',
#         'area': 'Öffentlich',
#         'pagelength': '20',
#         'language': 'de'
#     },
#     'List': [
#         {
#             'Code': '61241BM001',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# Deutschland insgesamt, Monate, Jahr',
#             'State': 'vollständig mit Werten',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:00:44h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM002',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (2-Steller): Gewerbliche Produkte, Deutschland insgesamt, Monate, Jahr',
#             'State': 'vollständig mit Werten',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:00:38h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM003',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (3-Steller): Gewerbliche Produkte, Deutschland insgesamt, Monate, Jahr',
#             'State': 'vollständig mit Werten',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:01:02h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM004',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (4-Steller): Gewerbliche Produkte, Deutschland insgesamt, Monate, Jahr',
#             'State': 'vollständig mit Werten',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:00:58h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM005',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (5-Steller): Gewerbliche Produkte, Deutschland insgesamt, Monate, Jahr',
#             'State': 'vollständig mit Werten',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:00:54h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM006',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (6-Steller): Gewerbliche Produkte, Deutschland insgesamt, Monate, Jahr',
#             'State': 'vollständig mit Werten',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:01:08h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM007',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (ausgewählte 9-Steller): Gewerbl. Produkte, Deutschland insgesamt, Monate, Jahr',
#             'State': 'vollständig mit Werten',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:00:50h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM008',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreisindex gewerblicher Produkte,
# GP2019 (Sonderpositionen): Gewerbliche Produkte, Deutschland insgesamt, Monate, Jahr',
#             'State': 'vollständig mit Werten',
#             'Time': 'Januar 2021-Februar 2024',
#             'LatestUpdate': '20.03.2024 08:00:41h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM010',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreise für leichtes Heizöl, Art der
# Lieferung (leichtes Heizöl), Berichtsort bzw. Geltungsbereich (leichtes Heizöl), Monate, Jahr',
#             'State': 'vollständig mit Werten',
#             'Time': 'Januar 1976-März 2024',
#             'LatestUpdate': '12.04.2024 08:04:59h',
#             'Information': 'false'
#         },
#         {
#             'Code': '61241BM011',
#             'Content': 'Index der Erzeugerpreise gewerblicher Produkte, Erzeugerpreise für schweres Heizöl, Art der
# Lieferung (schweres Heizöl), Berichtsort bzw. Geltungsbereich (schweres Heizöl), Monate, Jahr',
#             'State': 'vollständig mit Werten',
#             'Time': 'Januar 1991-Dezember 2016',
#             'LatestUpdate': '21.02.2017 16:08:54h',
#             'Information': 'false'
#         }
#     ],
#     'Copyright': '© Statistisches Bundesamt (Destatis), 2024'
# }

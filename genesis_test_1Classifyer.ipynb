# %%
import json
import requests
import csv
import io
from rich import print as rprint
import pandas as pd
import pprint

pp = pprint.PrettyPrinter(depth=4)

genesis_url = 'https://www-genesis.destatis.de/genesisWS/rest/2020/data/cube?'
user_id = 'DE17T29R57'
password = '4Bf/3Ap)3]r2,,h'
tab_code = '62221BV002'
area_type = 'all'
content = 'VST066'
start_year = ''  # '2018'
classifiyer1 = 'WZ08C7'
classifiyer2 = 'WZ08C7'
classifyingkey1 = 'WZ08-D-06'
classifyingkey2 = 'WZ08-D-06'
lang = 'en'

# Open API URL
destatis = f"{genesis_url}username={user_id}&password={password}&name={tab_code}&area={area_type}&compress=true&contents={content}&startyear={start_year}&classifyingvariable1={classifiyer1}&classifyingkey1={classifyingkey1}&language={lang}"

# get data from GENESIS API, converts it to JSON, get the CSV content and splits the lines
responseContent = json.loads(requests.get(destatis).text)["Object"]['Content'].split('\n')

# %%
# add a new line with the field names to the CSV content, eliminating unecessary lines
parsedContent = ['field_D;classifyingkey1;field_DFDN;quarter;year;value;field_e;field_;field__'] + responseContent[14:]

# convert into list of dicts
csvReader = csv.DictReader(io.StringIO('\n'.join(parsedContent)), delimiter=';', lineterminator='\n')
lstoDict = []
for row in csvReader:
    lstoDict.append(row)

# %%
# initialize the result object
result = {
    'tab_code': tab_code,
    'content': content,
    'classifiyer1': classifiyer1,
    'classifyingkey1': classifyingkey1,
    'data': []
}

# %%
#convert List of dictionaries to dataframe
df = pd.DataFrame(lstoDict)

df1 = df[['quarter','year','value']]
df1
# Out:
#     quarter  year  value
# 0    QUART1  1995   57.3
# 1    QUART1  1996   59.3
# 2    QUART1  1997   60.3
# 3    QUART1  1998   61.3
# 4    QUART1  1999   61.6
# ..      ...   ...    ...
# 227  QUART4  2019   98.9
# 228  QUART4  2020  100.9
# 229  QUART4  2021  102.9
# 230  QUART4  2022  104.5
# 231  QUART4  2023  107.4
#
# [232 rows x 3 columns]

# %%
from rich import print as rprint

# loop through a list of years in order to form a JSON object easy to read
years = list(dict.fromkeys([obj['year'] for obj in lstoDict]))
for year in years:
    yearData = {'year': year}
    df = []
    # loop through CSV lines separated by year
    for obj in [obj for obj in lstoDict if obj['year'] == year]:
        quarterValue = {'quarter': obj['quarter'], 'value': obj['value']}
        # split result in 'DF' or 'DN' (need to understand what it means, as there are quartes for this DF and for DN)
        df.append(quarterValue)

    yearData.update({'df': df})
    result['data'].append(yearData)

rprint(json.dumps(result, indent=4))
# Out:
# {
#     "tab_code": "62221BV002",
#     "content": "VST066",
#     "classifiyer1": "WZ08C7",
#     "classifyingkey1": "WZ08-D-06",
#     "data": [
#         {
#             "year": "1995",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "57.3"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "57.3"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "59.3"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "59.3"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "50.6"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "52.9"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "53.6"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "53.9"
#                 }
#             ]
#         },
#         {
#             "year": "1996",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "59.3"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "59.3"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "59.7"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "59.7"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "54.0"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "56.1"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "56.1"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "56.1"
#                 }
#             ]
#         },
#         {
#             "year": "1997",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "60.3"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "60.3"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "60.5"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "60.6"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "56.3"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "56.9"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "57.5"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "57.7"
#                 }
#             ]
#         },
#         {
#             "year": "1998",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "61.3"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "61.3"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "61.4"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "61.4"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "57.9"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "57.9"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "58.6"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "58.9"
#                 }
#             ]
#         },
#         {
#             "year": "1999",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "61.6"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "62.7"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "63.2"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "63.2"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "58.9"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "59.5"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "60.7"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "60.7"
#                 }
#             ]
#         },
#         {
#             "year": "2000",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "63.4"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "63.4"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "63.4"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "64.1"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "60.7"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "60.7"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "60.7"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "62.3"
#                 }
#             ]
#         },
#         {
#             "year": "2001",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "64.2"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "64.5"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "64.5"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "65.5"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "62.6"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "62.6"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "62.6"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "63.1"
#                 }
#             ]
#         },
#         {
#             "year": "2002",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "65.5"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "65.5"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "65.7"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "65.8"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "65.2"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "65.2"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "65.2"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "65.2"
#                 }
#             ]
#         },
#         {
#             "year": "2003",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "67.1"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "67.2"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "67.4"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "67.4"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "65.8"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "67.5"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "67.5"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "67.5"
#                 }
#             ]
#         },
#         {
#             "year": "2004",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "67.9"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "68.1"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "68.4"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "68.4"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "68.6"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "69.3"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "69.6"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "69.6"
#                 }
#             ]
#         },
#         {
#             "year": "2005",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "68.2"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "68.5"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "68.9"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "68.9"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "70.7"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "70.7"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "70.7"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "70.7"
#                 }
#             ]
#         },
#         {
#             "year": "2006",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "68.9"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "70.0"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "70.0"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "70.0"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "70.7"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "72.2"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "72.2"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "72.2"
#                 }
#             ]
#         },
#         {
#             "year": "2007",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "70.4"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "71.7"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "71.7"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "71.7"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "72.2"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "73.9"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "74.0"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "74.0"
#                 }
#             ]
#         },
#         {
#             "year": "2008",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "73.4"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "74.7"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "75.0"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "75.0"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "75.2"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "75.3"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "77.5"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "77.5"
#                 }
#             ]
#         },
#         {
#             "year": "2009",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "75.7"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "76.7"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "77.6"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "77.6"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "77.9"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "77.9"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "80.1"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "80.1"
#                 }
#             ]
#         },
#         {
#             "year": "2010",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "78.3"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "78.6"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "79.0"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "79.0"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "80.4"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "80.4"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "80.4"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "80.4"
#                 }
#             ]
#         },
#         {
#             "year": "2011",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "80.1"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "80.3"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "80.7"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "80.7"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "82.4"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "82.4"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "82.4"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "82.5"
#                 }
#             ]
#         },
#         {
#             "year": "2012",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "81.7"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "83.0"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "83.3"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "83.4"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "84.3"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "85.2"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "85.2"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "85.2"
#                 }
#             ]
#         },
#         {
#             "year": "2013",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "84.8"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "84.9"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "85.3"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "85.7"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "85.6"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "86.7"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "87.3"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "87.5"
#                 }
#             ]
#         },
#         {
#             "year": "2014",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "86.2"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "86.3"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "87.8"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "87.8"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "87.5"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "88.3"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "89.4"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "89.4"
#                 }
#             ]
#         },
#         {
#             "year": "2015",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "88.5"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "89.6"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "89.9"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "89.9"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "89.7"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "91.3"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "91.7"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "91.7"
#                 }
#             ]
#         },
#         {
#             "year": "2016",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "90.0"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "90.1"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "91.1"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "91.6"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "91.7"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "91.7"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "92.3"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "92.6"
#                 }
#             ]
#         },
#         {
#             "year": "2017",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "92.7"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "93.2"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "93.3"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "93.3"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "93.3"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "94.7"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "94.7"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "94.8"
#                 }
#             ]
#         },
#         {
#             "year": "2018",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "93.5"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "93.9"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "95.3"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "96.0"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "94.9"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "94.9"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "95.5"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "96.1"
#                 }
#             ]
#         },
#         {
#             "year": "2019",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "96.3"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "98.5"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "98.7"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "99.0"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "96.4"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "98.8"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "98.9"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "98.9"
#                 }
#             ]
#         },
#         {
#             "year": "2020",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "99.3"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "100.1"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "100.3"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "100.3"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "99.1"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "99.5"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "100.5"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "100.9"
#                 }
#             ]
#         },
#         {
#             "year": "2021",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "100.6"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "102.0"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "102.1"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "102.1"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "101.0"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "101.8"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "102.6"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "102.9"
#                 }
#             ]
#         },
#         {
#             "year": "2022",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "102.1"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "103.6"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "103.8"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "104.0"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "102.9"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "103.9"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "104.0"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "104.5"
#                 }
#             ]
#         },
#         {
#             "year": "2023",
#             "df": [
#                 {
#                     "quarter": "QUART1",
#                     "value": "104.7"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "105.6"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "106.6"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "106.8"
#                 },
#                 {
#                     "quarter": "QUART1",
#                     "value": "104.9"
#                 },
#                 {
#                     "quarter": "QUART2",
#                     "value": "105.0"
#                 },
#                 {
#                     "quarter": "QUART3",
#                     "value": "105.6"
#                 },
#                 {
#                     "quarter": "QUART4",
#                     "value": "107.4"
#                 }
#             ]
#         }
#     ]
# }
